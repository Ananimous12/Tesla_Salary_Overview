# %%
# Dataset: https://www.payscale.com/research/US/Employer=Tesla_Motors/Salary

# %%
# Import the modules and the dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor


data = pd.read_csv('Tesla_Salary.csv')
data.head(20)
# Out:
#                                         Job Title          Range    Average
# 0                               Software Engineer   $86k - $151k  $115,500
# 1                             Mechanical Engineer   $71k - $125k   $93,142
# 2                                Process Engineer   $69k - $110k   $87,390
# 3                 Technical Program Manager (TPM)   $83k - $141k  $112,302
# 4                          Manufacturing Engineer   $72k - $127k   $95,854
# 5                        Senior Software Engineer   $96k - $183k  $135,845
# 6                      Mechanical Design Engineer   $75k - $132k   $97,787
# 7                               Controls Engineer   $85k - $146k  $112,492
# 8   Project Manager, (Unspecified Type / General)   $54k - $137k   $85,846
# 9                         Global Sourcing Manager   $78k - $138k  $108,314
# 10                            Electrical Engineer   $71k - $158k  $100,497
# ...

# %%
# Data Preprocessing

x = data.iloc[:, 2].values
y = data.iloc[:, 2].values

data.head()
# Out:
#                          Job Title         Range    Average
# 0                Software Engineer  $86k - $151k  $115,500
# 1              Mechanical Engineer  $71k - $125k   $93,142
# 2                 Process Engineer  $69k - $110k   $87,390
# 3  Technical Program Manager (TPM)  $83k - $141k  $112,302
# 4           Manufacturing Engineer  $72k - $127k   $95,854

# %%
# TODO: I want to take the average of the 'Range'
# TODO: Then, I want to compare the difference between the range average to 'Average' salary
# TODO: Finally, I want to see which 'Job Title' has the hightest 'Average' compared to the salary range.

# %%
for i in data['Range']:
    splt = i.split(' - ')
    print(f'{splt[0]}, {splt[-1]}')
# Out:
# $86k, $151k
# $71k, $125k
# $69k, $110k
# $83k, $141k
# $72k, $127k
# $96k, $183k
# $75k, $132k
# $85k, $146k
# $54k, $137k
# $78k, $138k
# $71k, $158k
# $60k, $102k
# $69k, $138k
# $93k, $169k
# $82k, $219k
# $67k, $135k
# $89k, $155k
# $106k, $196k
# $63k, $105k
# $48k, $99k
# $62k, $114k
# $54k, $144k
# $63k, $129k
# $56k, $112k (Estimated *)
# $64k, $96k (Estimated *)
# $91k, $160k (Estimated *)
# $61k, $128k (Estimated *)
# $58k, $139k (Estimated *)
# $67k, $134k (Estimated *)
# $82k, $161k (Estimated *)
# $58k, $119k (Estimated *)
# $91k, $147k (Estimated *)
# $34k, $71k (Estimated *)
# $81k, $156k (Estimated *)
# $117k, $242k (Estimated *)
# $97k, $185k (Estimated *)
# $81k, $130k (Estimated *)
# $80k, $135k (Estimated *)
# $82k, $163k (Estimated *)
# $78k, $163k (Estimated *)
# $65k, $119k (Estimated *)
# $44k, $96k (Estimated *)
# $61k, $103k (Estimated *)
# $54k, $167k (Estimated *)
# $89k, $139k (Estimated *)
# $85k, $180k (Estimated *)
# $66k, $150k (Estimated *)
# ...
